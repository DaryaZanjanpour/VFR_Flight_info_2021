# %%
print("Welcome to Canadian Flyers! I am your virtual assistant! :)")
aeroplane = input("Enter the aeroplane Registrtion C172 (use caps lock / 4 required):")
pilot_weight = input("Enter the pilot weigth in pound:")
front_female_passenger = input("Enter the number of female front seat passenger")
front_male_passenger = input("Enter the number of male front seat passenger")
front_child_passenger = input("Enter the number of child front seat passenger")
aft_female_passenger = input("Enter the number of female aft seat passenger")
aft_male_passenger = input("Enter the number of male aft seat passenger")
aft_child_passenger = input("Enter the number of child aft seat passenger")
Baggage_area1 = input("Enter the weight of baggagees in area 1 in Pound")
Baggage_area2 = input("Enter the weight of baggagees in area 2 in Pound")
fuel = input("Enter the fuel loaded in Gal:")
fuel_runup = input("Enter the runup fuel in Gal:")
fuel_burn = input( "Enter Fuel Burn to Destination in gal:" )
print("_________________________________________")
print("_________________________________________")
print("Aeroplane type: C172-"+aeroplane)
print("Pilot weight:", pilot_weight + "Lbs")
print("number of front female passenger:", front_female_passenger)
print("number of front male passenger:", front_male_passenger)
print("number of front child passenger:", front_child_passenger)
print("number of aft female passenger:", aft_female_passenger)
print("number of aft male passenger:", aft_male_passenger)
print("number of aft child passenger:", aft_child_passenger)
print("Baggage weight area 1:", Baggage_area1 , "LBS")
print("Baggage weight area 2:", Baggage_area2 , "LBS")
print("Fuel loaded:", fuel , "gal")
print("Fuel Runup:", fuel_runup, "gal")
print("Fuel burn to destination" , fuel_burn , "gal")
aeroplane=str(aeroplane)
if aeroplane == "GLRU":
    Basic_empty_weight= 1420.0
    Moment = 55563.5
    CG = 39.1
    Maximum_Takeoff_weight= 2300
    Usable_Fuel= 38 
    Equipment= "SO/C"
    print("Basic empty weight= 1420.0")
    print("Moment = 55563.5")
    print("CG = 39.1")
    print("Maximum Takeoff weight= 2300")
    print("Usable Fuel= 38 Gal")
    print("Equipment= SO/C")
elif aeroplane == "FGPZ":
    Basic_empty_weight= 1464.9
    Moment = 57453.3
    CG = 39.4
    Maximum_Takeoff_weight= 2300
    Usable_Fuel= 38 
    Equipment= "SFO/C"
    print("Basic empty weight= 1464.9")
    print("Moment = 57483.3")
    print("CG = 39.24")
    print("Maximum Takeoff weight= 2300")
    print("Usable Fuel= 38 Gal")
    print("Equipment= SFO/C")
elif aeroplane == "GHKI":
    Basic_empty_weight= 1440.55
    Moment = 56821.63
    CG = 39.4
    Maximum_Takeoff_weight= 2300
    Usable_Fuel= 38 
    Equipment= "SG/C"
    print("Basic empty weight= 1440.55")
    print("Moment = 56821.63")
    print("CG = 39.4")
    print("Maximum Takeoff weight= 2300")
    print("Usable Fuel= 38 Gal")
    print("Equipment= SG/C")
elif aeroplane == "GPTJ":
    Basic_empty_weight= 1446.3
    Moment = 57246.32
    CG = 39.58
    Maximum_Takeoff_weight= 2300
    Usable_Fuel= 38 
    Equipment= "SG/C"
    print("Basic empty weight= 1446.3")
    print("Moment = 57246.32")
    print("CG = 39.58")
    print("Maximum Takeoff weight= 2300")
    print("Usable Fuel= 38 Gal")
    print("Equipment= SG/C")
elif aeroplane == "GPZI":
    Basic_empty_weight= 1499.91
    Moment = 60224.96
    CG = 40.15
    Maximum_Takeoff_weight= 2300
    Usable_Fuel= 48
    Equipment= "VFO/C"
    print("Basic empty weight= 1499.91")
    print("Moment = 60224.96")
    print("CG = 40.15")
    print("Maximum Takeoff weight= 2300")
    print("Usable Fuel= 48 Gal")
    print("Equipment= VFO/C")
elif aeroplane == "GQFA":
    Basic_empty_weight= 1434.4
    Moment = 57029.1
    CG = 39.8
    Maximum_Takeoff_weight= 2300
    Usable_Fuel= 38
    Equipment= "No Data"
    print("Basic empty weight= 1434.4")
    print("Moment = 57029.1")
    print("CG = 39.8")
    print("Maximum Takeoff weight= 2300")
    print("Usable Fuel= 38 Gal")
    print("Equipment= NO DATA")
elif aeroplane == "GKWL":
    Basic_empty_weight= 1466.65
    Moment = 55442.44
    CG = 39.17
    Maximum_Takeoff_weight= 2400
    Usable_Fuel= 50
    Equipment= "SGF/C"
    print("Basic empty weight= 1466.65")
    print("Moment = 55442.44")
    print("CG = 39.17")
    print("Maximum Takeoff weight= 2400")
    print("Usable Fuel= 50 Gal")
    print("Equipment= SGF/C")
elif aeroplane == "GYGQ":
    Basic_empty_weight= 1426.70
    Moment = 55716.20
    CG = 39.05
    Maximum_Takeoff_weight= 2300
    Usable_Fuel= 40
    Equipment= "VGFOD/C"
    print("Basic empty weight= 1426.70")
    print("Moment = 55716.20")
    print("CG = 39.05")
    print("Maximum Takeoff weight= 2300")
    print("Usable Fuel= 40 Gal")
    print("Equipment= VGFOD/C")
elif aeroplane == "GLJM":
    Basic_empty_weight= 2481.95
    Moment = 211278.92
    CG = 85.12
    Maximum_Takeoff_weight= 3800
    Usable_Fuel= 108
    Equipment= "SVGFO/C"
    print("Basic empty weight= 2481.95")
    print("Moment = 211278.92")
    print("CG = 85.12")
    print("Maximum Takeoff weight= 3800")
    print("Usable Fuel= 108 Gal")
    print("Equipment= SVGFO/C")
else:
    print("Sorry but we dont have this plane! check your reg code!")

from tabulate import tabulate

if aeroplane == 'GLJM':
    pilot_weight = int(pilot_weight)
    front_female_passenger=int(front_female_passenger)
    front_male_passenger=int(front_male_passenger)
    front_child_passenger=int(front_child_passenger)
    aft_female_passenger=int(aft_female_passenger)
    aft_male_passenger=int(aft_male_passenger)
    aft_child_passenger=int(aft_child_passenger)
    Moment = float(Moment)
    #---------------------------------------------------------------------
    total_front_wight = front_female_passenger*168 + front_male_passenger*203 + front_child_passenger*75 + pilot_weight
    moment_front=total_front_wight*80.5 
    
    #---------------------------------------------------------------------
    total_aft_weight = aft_female_passenger*168 + aft_male_passenger*203 + aft_child_passenger*75
    moment_aft=total_aft_weight*118.1
    #----------------------------------------------------------------------

    Baggage_area2 = int(Baggage_area2)
    Baggage_area1 = int(Baggage_area1)

    
    Baggage_area1_m = Baggage_area1*142.8

    #-----------------------------------------------------------------------
    #ZERO FUEL CONDITION 
    
    tot_zero_w =total_front_wight + total_aft_weight + Baggage_area1 +  Basic_empty_weight
    tot_zero_m =moment_front + moment_aft + Baggage_area1_m +  Moment
    cg_zero = tot_zero_m / tot_zero_w
    cg_zero =   "{:.2f}".format(cg_zero)
    #----------------------------------------------------------------------
    #fuel loading 
    #each gal == to 6 lBS
    fuel_i = int(fuel)
    fuel_w= fuel_i*6
    fuel_m=fuel_w*95
    #------------------------------------------------------------------
    #RAMP CONDITION 
    ramp_w=tot_zero_w+fuel_w
    ramp_m=tot_zero_m+fuel_m
    cg_ramp= ramp_m / ramp_w
    cg_ramp =  "{:.2f}".format(cg_ramp)
    
    #--------------------------------
    #start, taxi, runup 
    fuel_runupi= float(fuel_runup)
    runup_w= fuel_runupi*6
    runup_m=runup_w*95
    
    #--------------------------------------
    #Take off condition 
    takeoff_w=ramp_w - runup_w
    takeoff_m=ramp_m - runup_m
    cg_takeoff = takeoff_m / takeoff_w
    cg_takeoff= "{:.2f}".format(cg_takeoff)
    #----------------------------------------------------------------
    #fuel burn to destination
    
    fuel_burni = int(fuel_burn)
    fuelb_w = fuel_burni*6
    fuelb_m = fuelb_w*95
    #--------------------------------------------------------------------
    #Landing weight
    land_w=takeoff_w -fuelb_w
    land_m = takeoff_m - fuelb_m
    cg_land= land_m / land_w
    cg_land = "{:.2f}".format(cg_land)
    table = [['ITEM', 'WEIGHT (Lbs)', 'MOMENT (Lbs)', 'CG'], 
         ['BASIC EMPTY WEIGHT of '+aeroplane, Basic_empty_weight, Moment, CG],
         ['Front seat   FS 80.5', total_front_wight, moment_front,"-"],
         ['Aft seat     FS 118.1', total_aft_weight,moment_aft, "-"],
         ['Baggage Area 1   FS 142.8', Baggage_area1, Baggage_area1_m, "-"],
         ['***ZERO FUEL CONDITION***', tot_zero_w ,tot_zero_m, cg_zero],
         ['Fuel Loading ('+ fuel +' gal)', fuel_w,fuel_m, "-"],
         ['***RAMP CONDITION***', ramp_w, ramp_m,cg_ramp],
         ['Start, Taxi & Runup Fuel (1.1 gal)', runup_w,runup_m, "-"],
         ['TAKE OFF CONDITION', takeoff_w,takeoff_m,cg_takeoff],
         ['Fuel Burn to Destination (' + fuel_burn +' gal)', fuelb_w, fuelb_m,"-"],
         ['***LANDING CONDITION***', land_w, land_m,cg_land],
        ]
    print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))


if aeroplane != 'GLJM' :
    pilot_weight = int(pilot_weight)
    front_female_passenger=int(front_female_passenger)
    front_male_passenger=int(front_male_passenger)
    front_child_passenger=int(front_child_passenger)
    aft_female_passenger=int(aft_female_passenger)
    aft_male_passenger=int(aft_male_passenger)
    aft_child_passenger=int(aft_child_passenger)
    Moment = float(Moment)
    #---------------------------------------------------------------------
    total_front_wight = front_female_passenger*168 + front_male_passenger*203 + front_child_passenger*75 + pilot_weight
    moment_front=total_front_wight*37 
    
    #---------------------------------------------------------------------
    total_aft_weight = aft_female_passenger*168 + aft_male_passenger*203 + aft_child_passenger*75
    moment_aft=total_aft_weight*73
    #----------------------------------------------------------------------
    Baggage_area1 = int(Baggage_area1)
    Baggage_area2 = int(Baggage_area2)
    
    Baggage_area1_m = Baggage_area1*95
    Baggage_area2_m = Baggage_area2*123
    #-----------------------------------------------------------------------
    #ZERO FUEL CONDITION 
    
    tot_zero_w =total_front_wight + total_aft_weight + Baggage_area1 + Baggage_area2 +  Basic_empty_weight
    tot_zero_m =moment_front + moment_aft + Baggage_area1_m + Baggage_area2_m +  Moment
    cg_zero = tot_zero_m / tot_zero_w
    cg_zero =   "{:.2f}".format(cg_zero)
    #----------------------------------------------------------------------
    #fuel loading 
    #each gal == to 6 lBS
    fuel_i = int(fuel)
    fuel_w= fuel_i*6
    fuel_m=fuel_w*48
    #------------------------------------------------------------------
    #RAMP CONDITION 
    ramp_w=tot_zero_w+fuel_w
    ramp_m=tot_zero_m+fuel_m
    cg_ramp= ramp_m / ramp_w
    cg_ramp =  "{:.2f}".format(cg_ramp)
    
    #--------------------------------
    #start, taxi, runup 
    fuel_runupi= float(fuel_runup)
    runup_w=fuel_runupi*6
    runup_m=runup_w*48
    
    #--------------------------------------
    #Take off condition 
    takeoff_w=ramp_w - runup_w
    takeoff_m=ramp_m - runup_m
    cg_takeoff = takeoff_m / takeoff_w
    cg_takeoff= "{:.2f}".format(cg_takeoff)
    #----------------------------------------------------------------
    #fuel burn to destination
    
    fuel_burni = int(fuel_burn)
    fuelb_w = fuel_burni*6
    fuelb_m = fuelb_w*48
    #--------------------------------------------------------------------
    #Landing weight
    land_w=takeoff_w -fuelb_w
    land_m = takeoff_m - fuelb_m
    cg_land= land_m / land_w
    cg_land = "{:.2f}".format(cg_land)
    table = [['ITEM', 'WEIGHT (Lbs)', 'MOMENT (Lbs)', 'CG'], 
         ['BASIC EMPTY WEIGHT of '+aeroplane, Basic_empty_weight, Moment, CG],
         ['Front seat   FS 34-46(37)', total_front_wight, moment_front,"-"],
         ['Aft seat     FS 73', total_aft_weight,moment_aft, "-"],
         ['Baggage Area 1   FS 95', Baggage_area1, Baggage_area1_m, "-"],
         ['Baggage Area 2   FS 123', Baggage_area2, Baggage_area2_m, "-"],
         ['***ZERO FUEL CONDITION***', tot_zero_w ,tot_zero_m, cg_zero],
         ['Fuel Loading ('+ fuel +' gal)', fuel_w,fuel_m, "-"],
         ['***RAMP CONDITION***', ramp_w, ramp_m,cg_ramp],
         ['Start, Taxi & Runup Fuel (1.1 gal)', runup_w,runup_m, "-"],
         ['TAKE OFF CONDITION', takeoff_w,takeoff_m,cg_takeoff],
         ['Fuel Burn to Destination (' + fuel_burn +' gal)', fuelb_w, fuelb_m,"-"],
         ['***LANDING CONDITION***', land_w, land_m,cg_land],
        ]
    print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))

if aeroplane == "GLRU":
    if Baggage_area1+Baggage_area2 >119:
        print("Warning of Baggage weight! over than 120 lbs for C172 type! Reduce Baggage ")

if aeroplane == "FGPZ":
    if Baggage_area1+Baggage_area2 >119:
        print("Warning of Baggage weight! over than 120 lbs for C172 type! Reduce Baggage ")
        
if aeroplane == "GKWL":
    if Baggage_area1+Baggage_area2 >119:
        print("Warning of Baggage weight! over than 120 lbs for C172 type! Reduce Baggage ")
        
if aeroplane == "GHKI":
    if Baggage_area1+Baggage_area2 >119:
        print("Warning of Baggage weight! over than 120 lbs for C172 type! Reduce Baggage ")
        
if aeroplane == "GPTJ":
    if Baggage_area1+Baggage_area2 >119:
        print("Warning of Baggage weight! over than 120 lbs for C172 type! Reduce Baggage ")
        
if aeroplane == "GPZI":
    if Baggage_area1+Baggage_area2 >119:
        print("Warning of Baggage weight! over than 120 lbs for C172 type! Reduce Baggage ")
        
if aeroplane == "GQFA":
    if Baggage_area1+Baggage_area2 >119:
        print("Warning of Baggage weight! over than 120 lbs for C172 type! Reduce Baggage ")
        
if aeroplane == "GYGQ":
    if Baggage_area1+Baggage_area2 >119:
        print("Warning of Baggage weight! over than 120 lbs for C172 type! Reduce Baggage ")
             
if aeroplane == "GLRU":
    if takeoff_w > 2299:
        print("Warning! take off weight beyonds limit!")     
if aeroplane == "FPGZ":
    if takeoff_w > 2299:
        print("Warning! take off weight beyonds limit!")    
if aeroplane == "GHKI":
    if takeoff_w > 2299:
        print("Warning! take off weight beyonds limit!")     
if aeroplane == "GPTJ":
    if takeoff_w > 2299:
        print("Warning! take off weight beyonds limit!")  
if aeroplane == "GPZI":
    if takeoff_w > 2299:
        print("Warning! take off weight beyonds limit!")    
if aeroplane == "GQFA":
    if takeoff_w > 2299:
        print("Warning! take off weight beyonds limit!")     
if aeroplane == "GYGQ":
    if takeoff_w > 2299:
        print("Warning! take off weight beyonds limit!")    
if aeroplane == "GKWL":
    if takeoff_w > 2399:
        print("Warning! take off weight beyonds limit!")
if aeroplane == "GLJM":
    if takeoff_w > 3799:
        print("Warning! take off weight beyonds limit!")


cg_ramp = float(cg_ramp) 
ramp_w = float(ramp_w) /100
tot_zero_w = float(tot_zero_w) /100
cg_zero = float(cg_zero) 
takeoff_w = float(takeoff_w) /100
cg_takeoff = float(cg_takeoff) 
land_w = float(land_w) / 100
cg_land = float(cg_land)

import matplotlib.pyplot as plt
import numpy as np
#----------------------------------------------------


fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(1, 1, 1)

# Major ticks every 20, minor ticks every 5
major_ticks = np.arange(0, 230, 1)
minor_ticks = np.arange(0, 230, .2)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(major_ticks)
ax.set_yticks(minor_ticks, minor=True)

# And a corresponding grid
ax.grid(which='both')

# Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
#----------------------------------------------------
plt.ylabel('LOAD WEIGHT (POUNDS) CONVERSION: 10^2')
plt.xlabel('CG LOCATION')
x1, y1 =  [35, 35], [0, 19.50]
x2, y2 = [35, 38.5], [19.50, 23.00]
x3, y3 = [38.5, 47.2 ],[23.00, 23.00]
x4, y4 = [47.2, 47.2 ],[0, 23.00]
x5, y5 = [40.5,40.5], [0, 20]
x6, y6 = [40.5,35.6], [20, 20]
x7, y7 = [cg_zero, cg_ramp], [tot_zero_w, ramp_w]
x8 , y8 = [cg_ramp, cg_takeoff], [ramp_w, takeoff_w]
x9, y9 = [cg_takeoff,cg_land],[takeoff_w, land_w]
plt.plot(x1, y1, x2, y2, x3, y3, x4, y4, color= 'black')
plt.plot(x5, y5, 'k--')
plt.plot(x6, y6, 'k--')
plt.plot(x7, y7, 'g-')
plt.plot(x8, y8, 'y-')
plt.plot(x9, y9, 'b-')
plt.grid(b=None, which='both', axis='both')
plt.xlim(34,48)
plt.ylim(15.00,24.00)

plt.plot([cg_zero,tot_zero_w], 'g-',label='Ramp condition')
plt.plot([cg_takeoff, takeoff_w],'y-',label='Ramp to Takeoff')
plt.plot([cg_land, land_w],'b-',label='Takeoff to Land')


plt.text(42, 21.80, 'CENTER OF GRAVITY LIMITS', style='normal',
    bbox={'facecolor': 'white', 'alpha': 5, 'pad': 10})
plt.text(36.8, 17, 'UTILITY CATEGORY', style='normal', size= '10',
    bbox={'facecolor': 'white', 'alpha': 5, 'pad': 10})
plt.text(42.8, 17, 'NORMAL CATEGORY', style='normal',
    bbox={'facecolor': 'white', 'alpha': 5, 'pad': 10})

plt.legend()
plt.show()
#--------------------------------------------------------------------------------
# Out:
# Welcome to Canadian Flyers! I am your virtual assistant! :)
# Enter the aeroplane Registrtion C172 (use caps lock / 4 required): GHKI
# Enter the pilot weigth in pound: 170
# Enter the number of female front seat passenger 0
# Enter the number of male front seat passenger 0
# Enter the number of child front seat passenger 0
# Enter the number of female aft seat passenger 0
# Enter the number of male aft seat passenger 0
# Enter the number of child aft seat passenger 0
# Enter the weight of baggagees in area 1 in Pound 0
# Enter the weight of baggagees in area 2 in Pound 0
# Enter the fuel loaded in Gal: 38
# Enter the runup fuel in Gal: 1
# Enter Fuel Burn to Destination in gal: 16
# _________________________________________
# _________________________________________
# Aeroplane type: C172-GHKI
# Pilot weight: 170Lbs
# number of front female passenger: 0
# number of front male passenger: 0
# number of front child passenger: 0
# number of aft female passenger: 0
# ...

# %%
#import sys
#sys.path.append('/.../Storage/Darya/persistent/KWL/pytafP')
import pytaf
from metar import Metar
weather = input("copy paste the last line of METAR here!")
taf = input('copy paste the TAF here!')
print("---------------------------------------------------------------------------------------------------")
print("METAR station 1")
print("---------------------------------------------------------------------------------------------------")

obs = Metar.Metar(weather)
taf = pytaf.TAF(taf)
decoder = pytaf.Decoder(taf)
print(obs.string())
print("---------------------------------------------------------------------------------------------------")
print('TAF station 1')
print("---------------------------------------------------------------------------------------------------")
print(decoder.decode_taf())
# Out:
# copy paste the last line of METAR here! METAR CYYZ 121800Z 13008G15KT 060V160 15SM FEW080 FEW140 FEW250 24/10 A2989 RMK AC1AC1CI1 AC TR AC TR CI TR SLP122 DENSITY ALT 1800F T=
# copy paste the TAF here! TAF CYYZ 121738Z 1218/1324 13010KT P6SM FEW080 FM130400 VRB03KT P6SM BKN050 FM130800 VRB03KT P6SM BKN050 TEMPO 1308/1315 P6SM -SHRA FM131500 17008KT P6SM BKN040 FM131800 16010KT P6SM SCT050 FM132100 VRB03KT P6SM -SHRA BKN050 RMK NXT FCST BY 122100Z=
# ---------------------------------------------------------------------------------------------------
# METAR station 1
# ---------------------------------------------------------------------------------------------------
# station: CYYZ
# type: routine report, cycle 18 (automatic report)
# time: Sat Jun 12 18:00:00 2021
# temperature: 24.0 C
# dew point: 10.0 C
# wind: ENE to SSE at 8 knots, gusting to 15 knots
# visibility: 15 miles
# pressure: 1012.2 mb
# sky: a few clouds at 8000 feet
#      a few clouds at 14000 feet
# ...

# %%
#import sys
#sys.path.append('/.../Storage/Darya/persistent/KWL/pytafP')
import pytaf
from metar import Metar
weather = input("copy paste the last line of METAR here!")
taf = input('copy paste the TAF here!')
print("---------------------------------------------------------------------------------------------------")
print("METAR station 2")
print("---------------------------------------------------------------------------------------------------")

obs = Metar.Metar(weather)
taf = pytaf.TAF(taf)
decoder = pytaf.Decoder(taf)
print(obs.string())
print("---------------------------------------------------------------------------------------------------")
print('TAF station 2')
print("---------------------------------------------------------------------------------------------------")
print(decoder.decode_taf())

# %%
#import sys
#sys.path.append('/.../Storage/Darya/persistent/KWL/pytafP')
import pytaf
from metar import Metar
weather = input("copy paste the last line of METAR here!")
taf = input('copy paste the TAF here!')
print("---------------------------------------------------------------------------------------------------")
print("METAR station 3")
print("---------------------------------------------------------------------------------------------------")

obs = Metar.Metar(weather)
taf = pytaf.TAF(taf)
decoder = pytaf.Decoder(taf)
print(obs.string())
print("---------------------------------------------------------------------------------------------------")
print('TAF station 3')
print("---------------------------------------------------------------------------------------------------")
print(decoder.decode_taf())

# %% [markdown]
# upper wind: 140 true and 6 knots

# %%
import math
#------------------------------------------------------------
#extract data
obs = Metar.Metar(weather)
string= obs.string()
string=string.split("\n")
#print(obs.string())
string
#-------------------------------
'''
         ['Elevation'
         ['Altimeter setting'
         ['Pressure Altitude'
         ['Tempreture',
         ['Densty Altitude'
         ['Runway'
         ['TORA'
         ['TODA'
         ['ASDA'
         ['Wind',
         ['H-wind
         ['T-wind
         ['G-Run / H Factor 
         ['T-Distance / H Factor'
         ['Ground Run
         ['Takeoff Distance'
'''
#---------------------------------------------------------------
#sea-level pressure: (Altimeter setting)
matching_slp = [s for s in string if "sea-level pressure" in s]
first=matching_slp[0].find(":")
last=matching_slp[0].find("m")

matching_slp=matching_slp[0][first+2:last-1]
SLP=float(matching_slp)
#----------------------------------------------------------------
#Altimeter setting
matching_alt = [s for s in string if "RMK" in s]
matching_alt[0]

first=matching_alt[0].find("RMK")
#last=matching_alt[0].find("m")
#first
matching_alt=matching_alt[0][first-5:first-1]
matching_alt=float(matching_alt)
ALT=matching_alt/100
#----------------------------------------------------------------
#pressure altitude = (standard pressure - your current pressure setting) x 1,000 + field elevation
field_elv = input("Enter the field elevation (CYKZ = 650) =")
field_elv=float(field_elv)
p_0  = 29.92
pre_alt = (p_0-ALT)*1000+ field_elv
int(pre_alt)
ALT

# %%
#---------------------------------------------------------------
#Altimeter setting
matching_alt = [s for s in string if "RMK" in s]
matching_alt[0]

first=matching_alt[0].find("RMK")
#last=matching_alt[0].find("m")
#first
matching_alt=matching_alt[0][first-5:first-1]
matching_alt=float(matching_alt)
ALT=matching_alt/100
#----------------------------------------------------------------
#pressure altitude = (standard pressure - your current pressure setting) x 1,000 + field elevation
field_elv = input("Enter the field elevation (CYKZ = 650) =")
field_elv=float(field_elv)
p_0  = 29.92
pre_alt = (p_0-ALT)*1000+ field_elv
pre_alt

# %%
print("Welcome to Canadian Flyers! I am your virtual assistant! :)")
elevation= input("Enter the elevation (cykz = 650):")
lnter the altmieter setting = input("Enter the pilot weigth in pound:")
front_female_passenger = input("Enter the number of female front seat passenger")
front_male_passenger = input("Enter the number of male front seat passenger")
front_child_passenger = input("Enter the number of child front seat passenger")
aft_female_passenger = input("Enter the number of female aft seat passenger")
aft_male_passenger = input("Enter the number of male aft seat passenger")
aft_child_passenger = input("Enter the number of child aft seat passenger")
Baggage_area1 = input("Enter the weight of baggagees in area 1 in Pound")
Baggage_area2 = input("Enter the weight of baggagees in area 2 in Pound")
fuel = input("Enter the fuel loaded in Gal:")
fuel_runup = input("Enter the runup fuel in Gal:")
fuel_burn = input( "Enter Fuel Burn to Destination in gal:" )
print("_________________________________________")
print("_________________________________________")
print("Aeroplane type: C172-"+aeroplane)
print("Pilot weight:", pilot_weight + "Lbs")
print("number of front female passenger:", front_female_passenger)
print("number of front male passenger:", front_male_passenger)
print("number of front child passenger:", front_child_passenger)
print("number of aft female passenger:", aft_female_passenger)
print("number of aft male passenger:", aft_male_passenger)
print("number of aft child passenger:", aft_child_passenger)
print("Baggage weight area 1:", Baggage_area1 , "LBS")
print("Baggage weight area 2:", Baggage_area2 , "LBS")
print("Fuel loaded:", fuel , "gal")
print("Fuel Runup:", fuel_runup, "gal")
print("Fuel burn to destination" , fuel_burn , "gal")


table = [['DATA    /    STAGE','DEPARTURE DATA', 'CRUISE DATA','ARRIVIAL DATA'],
         ['Elevation','John', 'Smith', 39],
         ['Altimeter setting','Mary', 'Jane', 25],
         ['Pressure Altitude','Jennifer', 'Doe', 28],
         ['Tempreture','Jennifer', 'Doe', 28],
         ['Densty Altitude','Jennifer', 'Doe', 28],
         ['Runway','Jennifer', 'Doe', 28],
         ['TORA','Jennifer', 'Doe', 28],
         ['TODA','Jennifer', 'Doe', 28],
         ['ASDA','Jennifer', 'Doe', 28],
         ['Wind','Jennifer', 'Doe', 28],
         ['H-wind','Jennifer', 'Doe', 28],
         ['T-wind','Jennifer', 'Doe', 28],
         ['G-Run / H Factor ','Jennifer', 'Doe', 28],
         ['T-Distance / H Factor','Jennifer', 'Doe', 28],
         ['Ground Run','Jennifer', 'Doe', 28],
         ['Takeoff Distance','Jennifer', 'Doe', 28]
        ]
print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))

# %%
odfkg  xv
